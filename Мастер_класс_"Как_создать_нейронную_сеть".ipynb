# %% [markdown]
# <a href="https://colab.research.google.com/github/eselse/Advanced-React-and-GraphQL/blob/main/%D0%9C%D0%B0%D1%81%D1%82%D0%B5%D1%80_%D0%BA%D0%BB%D0%B0%D1%81%D1%81_%22%D0%9A%D0%B0%D0%BA_%D1%81%D0%BE%D0%B7%D0%B4%D0%B0%D1%82%D1%8C_%D0%BD%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BD%D1%83%D1%8E_%D1%81%D0%B5%D1%82%D1%8C%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/My Drive')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Кошки против собак

# %%
# Подключение модуля ai_university.convolutional
import ai_university.convolutional as convNet

# %%
# Инициализация модели
convNet.initialize('Кошки против собак')
# Out:
# Загружены изображения кошек: 12500 шт.
# Загружены изображения собак: 12500 шт.

# %%
# Отображение 5ти случайных примеров
convNet.samples()
# Out:
# * Примеры изображений *

# %%
# Обучение модели
convNet.train_model()
# Out:
# * Эпоха: 1/20  | Точность (обучающая выборка): 66.65%        Точность (проверочная выборка): 50.45%
# * Эпоха: 2/20  | Точность (обучающая выборка): 84.52%        Точность (проверочная выборка): 58.45%
# * Эпоха: 3/20  | Точность (обучающая выборка): 88.34%        Точность (проверочная выборка): 62.12%
# * Эпоха: 4/20  | Точность (обучающая выборка): 93.21%        Точность (проверочная выборка): 65.56%
# * Эпоха: 5/20  | Точность (обучающая выборка): 94.32%        Точность (проверочная выборка): 70.23%
# * Эпоха: 6/20  | Точность (обучающая выборка): 96.23%        Точность (проверочная выборка): 75.44%
# * Эпоха: 7/20  | Точность (обучающая выборка): 97.65%        Точность (проверочная выборка): 73.12%
# * Эпоха: 8/20  | Точность (обучающая выборка): 98.34%        Точность (проверочная выборка): 78.34%
# * Эпоха: 9/20  | Точность (обучающая выборка): 98.21%        Точность (проверочная выборка): 82.23%
# ...

# %%
# Отображение процесса распознавания изображений
convNet.show_result()
# Out:
# * Эпоха:20  | Точность модели: 93.22%

# %% [markdown]
# # Предсказание цены квартиры

# %%
# Подключение модуля ai_university.regression
import ai_university.regression as regNet

# %%
# Инициализация модели
regNet.initialize('Оценка стоимости квартир')
# Out:
# Загружены объявления:  62504 шт.

# %%
regNet.samples()
# Out:
# * Пример объявления:
#
# Колчиество комнат:  1
# Площадь квартиры:   35/14/10
# Метро/ЖД станция:   Селигерская м.
# От станции:         12п
# Дом:                19/22 М
# Балкон:             Л
# Санузел:            Р
# Примечание:         Собственник. Срочная продажа.
# Продаю 1-комнатную квартира в новом доме клубного формата Бизнес класса. Точечная застройка.
# Видовая квартира с панорамное остекление!
# Огороженная ухоженная придомовая территория.
# Подземный паркинг. Английский детский садик на 1 этаже.
# Свободная планировка. Свободная продажа. Ключи. Собственность.
# Метро Селигерская - 5 минут пешком.
# Развитая обжитая инфраструктура района. Всё находится в пешей доступности. Во дворе находится много детских площадок и детская поликлиника, отреставрированный пруд, рядом лесная зона и городские парки. Торг.
# -----------
# Цена квартиры:     8 млн  0 тыс рублей
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
regNet.train_model()
# Out:
# * Эпоха: 1/70   | Ошибка (обучающая выборка): 2 млн. 237 тыс.   Ошибка (проверочная выборка):  1 млн. 447 тыс.
# * Эпоха: 2/70   | Ошибка (обучающая выборка): 2 млн. 23 тыс.    Ошибка (проверочная выборка):  1 млн. 361 тыс.
# * Эпоха: 3/70   | Ошибка (обучающая выборка): 1 млн. 237 тыс.   Ошибка (проверочная выборка):  1 млн. 237 тыс.
# * Эпоха: 4/70   | Ошибка (обучающая выборка): 966 тыс.          Ошибка (проверочная выборка):  1 млн. 165 тыс.
# * Эпоха: 5/70   | Ошибка (обучающая выборка): 919 тыс.          Ошибка (проверочная выборка):  1 млн. 318 тыс.
# * Эпоха: 6/70   | Ошибка (обучающая выборка): 846 тыс.          Ошибка (проверочная выборка):  1 млн. 145 тыс.
# * Эпоха: 7/70   | Ошибка (обучающая выборка): 817 тыс.          Ошибка (проверочная выборка):  1 млн. 470 тыс.
# * Эпоха: 8/70   | Ошибка (обучающая выборка): 725 тыс.          Ошибка (проверочная выборка):  975 тыс.
# ...

# %%
# Отображение процесса предсказания
regNet.show_process()
# Out:
# * Эпоха: 70   | Ошибка:  631 тыс.
